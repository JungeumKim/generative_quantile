# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.debugger import set_trace
from importlib import reload
import matplotlib.pyplot as plt

# %%
import sys
#sys.path.append("/home/kim2712/Desktop/research/conformal_tree/")
sys.path.append("/home/kim2712/Desktop/research/generative_quantile/generative_qunatile/brenier/")
sys.path.append("/home/kim2712/Desktop/research/generative_quantile/generative_qunatile")

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
warnings.filterwarnings("ignore", category=RuntimeWarning)

import torch
torch.autograd.set_detect_anomaly(True)
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils import data
import argparse
import numpy as np
import scipy

#our libs
import matplotlib.pyplot as plt
import seaborn as sns
#import utils
#from utils import truncated_normal
#from gen_data import *
#from torchvision import datasets, transforms, utils
from models import ConditionalConvexQuantile,dual_JK

# %%
from _utils.breiner_util import plot2d, histogram, plotaxis
from _data.gaussian_conjugate import forward_sampler, posterior_sampler

# %%
class args:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    gauss=False#True #False
    batch_size = 128 
    epoch = 150 
    n_iter= 100
    
    optimizer='adam'
    lr=0.01#05
    beta1 = 0.9 
    beta2=0.999
    nesterov=False
    iters=1000
    mean=0
    std=1    


    eps=0
    
    n_sample = 2

# %%
print("Input arguments:")
for key, val in vars(args).items():
    print("{:16} {}".format(key, val))
# Out:
# Input arguments:
# __module__       __main__
# device           cuda
# gauss            False
# batch_size       128
# epoch            150
# n_iter           100
# optimizer        adam
# lr               0.01
# beta1            0.9
# beta2            0.999
# nesterov         False
# iters            1000
# mean             0
# std              1
# eps              0
# n_sample         2
# __dict__         <attribute '__dict__' of 'args' objects>
# __weakref__      <attribute '__weakref__' of 'args' objects>
# __doc__          None

# %%
#HPARAM = {"nu":1, "sigma0_sq":1, "mu0":0,"kappa":2}
HPARAM = {"nu":25, "sigma0_sq":1, "mu0":0,"kappa":2}
#ds = Synthetic(args, n=args.n)
#loader = data.DataLoader(ds, batch_size=args.batch_size, shuffle=True, drop_last=True)

# %%
def unif(size, eps=1E-7, device ="cuda"):
    return torch.clamp(torch.rand(size).to(device), min=eps, max=1-eps)

np_random = np.random.RandomState(1234)

def train(net, HPARAM, args):

    #eg = Rings() # EightGaussian()
    gauss = torch.distributions.normal.Normal(torch.tensor([0.]).to(args.device), 
                                              torch.tensor([1.]).to(args.device))
    for epoch in range(1, args.epoch+1):
        optimizer = optim.Adam(net.parameters(), lr=args.lr*(0.99**2), betas=(args.beta1, args.beta2))
        running_loss = 0.0
        for idx in range(args.n_iter):
        #for idx, (Y, label) in enumerate(loader):
            Y, label = forward_sampler(n = args.n_sample, 
                                batch_size=args.batch_size,
                                device=args.device,
                                h_param=HPARAM,
                                as_torch = True,
                                np_random = np_random)
            u = unif(size=(args.batch_size, args.n_sample), 
                     device=args.device)
            if args.gauss:
                u = gauss.icdf(u)
            optimizer.zero_grad()
            X,_ = net.f(label.unsqueeze(1))
            alpha, beta= net(u)
            loss = dual_JK(U=u, Y_hat=(alpha, beta), Y=Y, X=X, eps=args.eps)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        if epoch % 10 == 0:
            print('%.5f' %
                (running_loss))#/(idx+1)))
            test(net, args, HPARAM)
            net.train()

    
def test(net, args, HPARAM, n_test = 500):
    theta, sigma_sq = posterior_sampler(X = torch.tensor([2.2,2.2]), batch_size=100)
    
    net.eval()
    gauss = torch.distributions.normal.Normal(torch.tensor([0.]).to(args.device), 
                                          torch.tensor([1.]).to(args.device))
    U = unif(size=(n_test, 2), device = args.device)
    if args.gauss:
        U = gauss.icdf(U)
    X = torch.ones((n_test,args.n_sample),
                          device=args.device)*2.2 #.long()
    #print(X)
    Y_hat,_ = net.grad(U, X.unsqueeze(1), onehot=False)#= net.forward(U, grad=True).sum()
    #Y_hat = net.grad(U)
    #print("max and min points generated: " + str(Y_hat.max()) + " " + str(Y_hat.min()))
    #plot(Y_hat, X ,HPARAM)
    Y_hat = Y_hat.detach().cpu()
    
    fig,axis = plt.subplots(1,2, figsize=(8,4), sharex=True, sharey=True)

    ax=axis[0]
    sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=False) #, cmap="Blues"
    sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=True) #, cmap="Blues"

    ax=axis[1]
    sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=False) #, cmap="Blues"
    sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=True) #, cmap="Blues"

    fig.tight_layout()
    plt.show()

# %%
net = ConditionalConvexQuantile(xdim=args.n_sample,
                                ydim=2, 
                                a_hid=512,
                                a_layers=3,
                                b_hid=512,
                                b_layers=3)

net.to(args.device)
0
# Out:
# 0

# %%
train(net, HPARAM, args)
# Out:
# 80.37716
# 80.65704
# 83.66228
# 86.49341
# 83.86894
# 83.23975
# 81.13590
# 80.20892
# 81.99031
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0a971013cb81> in <module>
# ----> 1 train(net, HPARAM, args)
#
# <ipython-input-8-a68c0a406506> in train(net, HPARAM, args)
#      24             if args.gauss:
#      25                 u = gauss.icdf(u)
# ---> 26             optimizer.zero_grad()
#      27             X,_ = net.f(label.unsqueeze(1))
#      28             alpha, beta= net(u)
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/pytorch-1.7.1/lib/python3.8/site-packages/torch/optim/optimizer.py in zero_grad(self, set_to_none)
#     182         for group in self.param_groups:
#     183             for p in group['params']:
# --> 184                 if p.grad is not None:
#     185                     if set_to_none:
#     186                         p.grad = None
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/pytorch-1.7.1/lib/python3.8/site-packages/torch/tensor.py in grad(self)
#     941         relevant_args = (self,)
#     942         from torch.overrides import has_torch_function, handle_torch_function
# --> 943         if type(self) is not Tensor and has_torch_function(relevant_args):
#     944             # TODO mypy doesn't support @property, see: https://github.com/python/mypy/issues/6185
#     945             return handle_torch_function(Tensor.grad.__get__, relevant_args, self)  # type: ignore[attr-defined]
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/pytorch-1.7.1/lib/python3.8/site-packages/torch/overrides.py in has_torch_function(relevant_args)
#    1081     implementations, False otherwise.
#    1082     """
# -> 1083     return _is_torch_function_enabled() and any(
#    1084         type(a) is not torch.Tensor and
#    1085         getattr(a, '__torch_function__', _disabled_torch_function_impl)
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/pytorch-1.7.1/lib/python3.8/site-packages/torch/overrides.py in <genexpr>(.0)
#    1082     """
#    1083     return _is_torch_function_enabled() and any(
# -> 1084         type(a) is not torch.Tensor and
#    1085         getattr(a, '__torch_function__', _disabled_torch_function_impl)
#    1086         is not _disabled_torch_function_impl
#
# KeyboardInterrupt:

# %%
n_test = 500
KK=1.2
theta, sigma_sq = posterior_sampler(X = torch.tensor([KK,KK]), 
                                                batch_size=args.batch_size,
                                                as_torch =False,seed=12334)
net.eval()
gauss = torch.distributions.normal.Normal(torch.tensor([0.]).to(args.device), 
                                          torch.tensor([1.]).to(args.device))
U = unif(size=(n_test, 2), device = args.device)
if args.gauss:
    U = gauss.icdf(U)
X = torch.ones((n_test,args.n_sample),
                      device=args.device)*2.2 #.long()
#print(X)
Y_hat,_ = net.grad(U, X.unsqueeze(1), onehot=False)#= net.forward(U, grad=True).sum()
#Y_hat = net.grad(U)
print("max and min points generated: " + str(Y_hat.max()) + " " + str(Y_hat.min()))
#plot(Y_hat, X ,HPARAM)
Y_hat = Y_hat.detach().cpu()
# Out:
# max and min points generated: tensor(2.9719, device='cuda:0', grad_fn=<MaxBackward1>) tensor(0.6654, device='cuda:0', grad_fn=<MinBackward1>)

# %%
import seaborn as sns

fig,axis = plt.subplots(1,2, figsize=(8,4))#, sharex=True, sharey=True)

ax=axis[0]
sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=False) #, cmap="Blues"
sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=True) #, cmap="Blues"

ax=axis[1]
sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=False) #, cmap="Blues"
sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=True) #, cmap="Blues"

plt.show()

import seaborn as sns

fig,axis = plt.subplots(1,2, figsize=(8,4), sharex=True, sharey=True)

ax=axis[0]
sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=False) #, cmap="Blues"
sns.kdeplot(x=theta, y=sigma_sq, ax=ax, fill=True) #, cmap="Blues"

ax=axis[1]
sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=False) #, cmap="Blues"
sns.kdeplot(x=Y_hat[:,0], y=Y_hat[:,1], ax=ax, fill=True) #, cmap="Blues"

plt.show()

# %%
import pathlib
path = "./trained_nets"
pathlib.Path(path).mkdir(parents=True, exist_ok=True)
torch.save(net.state_dict(),  path+F"/uniform_seed_all_x.net")

# %%
n_test = 500
theta, sigma_sq = posterior_sampler(X = torch.tensor([2.2,2.2]), 
                                                batch_size=args.batch_size,
                                                as_torch =False,
                                                np_random =np_random )
net.eval()
gauss = torch.distributions.normal.Normal(torch.tensor([0.]).to(args.device), 
                                          torch.tensor([1.]).to(args.device))
U = unif(size=(n_test, 2), device = args.device)
if args.gauss:
    U = gauss.icdf(U)
X = torch.ones((n_test,args.n_sample),
                      device=args.device)*2.2 #.long()
#print(X)
Y_hat,_ = net.grad(U, X.unsqueeze(1), onehot=False)#= net.forward(U, grad=True).sum()
#Y_hat = net.grad(U)
print("max and min points generated: " + str(Y_hat.max()) + " " + str(Y_hat.min()))
#plot(Y_hat, X ,HPARAM)
Y_hat = Y_hat.detach().cpu()
# Out:
# > /home/kim2712/Desktop/research/generative_quantile/generative_qunatile/brenier/models.py(376)grad()
#     374         if self.xdim != 0 and x != None:
#     375             set_trace()
# --> 376             phi += (torch.bmm(self.beta(u).unsqueeze(1), x.unsqueeze(-1)).squeeze(-1)).sum()
#     377         d_phi = torch.autograd.grad(phi, u, create_graph=True)[0]
#     378         return d_phi, xv
#
# ipdb> print(x.shape)
# torch.Size([500, 2])
# ipdb> print(x.unsqueeze(-1).shape)
# torch.Size([500, 2, 1])
# ipdb> self.beta(u).unsqueeze(1).shape
# torch.Size([500, 1, 2])
# ipdb> exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-32-aaacba7aaa22> in <module>
#      13                       device=args.device)*2.2 #.long()
#      14 #print(X)
# ---> 15 Y_hat,_ = net.grad(U, X.unsqueeze(1), onehot=False)#= net.forward(U, grad=True).sum()
#      16 #Y_hat = net.grad(U)
#      17 print("max and min points generated: " + str(Y_hat.max()) + " " + str(Y_hat.min()))
#
# ~/Desktop/research/generative_quantile/generative_qunatile/brenier/models.py in grad(self, u, x, onehot)
#     374         if self.xdim != 0 and x != None:
#     375             set_trace()
# --> 376             phi += (torch.bmm(self.beta(u).unsqueeze(1), x.unsqueeze(-1)).squeeze(-1)).sum()
#     377         d_phi = torch.autograd.grad(phi, u, create_graph=True)[0]
#     378         return d_phi, xv
#
# ~/Desktop/research/generative_quantile/generative_qunatile/brenier/models.py in grad(self, u, x, onehot)
#     374         if self.xdim != 0 and x != None:
#     375             set_trace()
# --> 376             phi += (torch.bmm(self.beta(u).unsqueeze(1), x.unsqueeze(-1)).squeeze(-1)).sum()
#     377         d_phi = torch.autograd.grad(phi, u, create_graph=True)[0]
#     378         return d_phi, xv
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/tensorflow-2.4.0/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /apps/gilbreth/ml/ml-toolkit/conda-2020.11-py38/gpu/install/tensorflow-2.4.0/lib/python3.8/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:
